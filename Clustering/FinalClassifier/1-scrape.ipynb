# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

import requests
from bs4 import BeautifulSoup
import json

# %%
input_url = "https://fr.trustpilot.com/review/"
extension = '.eu'

scrap_tag = {'card': 'div', 'title': 'h2', 'rating': 'div', 'review': 'p', 'date': 'p', 'reply': 'p'}
scrap_class = {'card': "styles_cardWrapper__LcCPA", 'title': 'typography_heading-s__f7029',
               'rating': 'styles_reviewHeader__iU9Px', 'review': 'typography_body-l__KUYFJ',
               'date': 'typography_body-m__xgxZ_', 'reply': 'typography_body-m__xgxZ_'}

matching_rule = {'1': '.\nJe ne suis pas content du tout.\n',
                 '2': '.\nJe ne suis pas content.\n',
                 '3': '.\nJe suis partagé.\n',
                 '4': '.\nJe suis content.\n',
                 '5': '.\nJe suis très content.\n'}

reactivity = ['réactivité', 'rapidité', 'disponibilité', 'joindre', 'joignable', 'disponible', 'instantané',
              'instantanément', 'rapidement', 'répond', 'réponse', 'compliqué', 'difficulté', 'difficile', 'long',
              'pénible', 'simple', 'sérieux',
              'facile', 'efficace', 'fluide', 'procédure', 'toujours pas']
price = ['compétitif', 'cher', 'prix', 'tarif']
offer = ['remboursement', 'règlement', 'sinistre', 'vol', 'déclaration']
labels = reactivity + price + offer

# %%
class NlpPipeline:

    def __init__(self):
        self.classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")

    def run(self, complete_reviews: [str]):
        results = [self.classifier(cr, labels, multilabel=True) for cr in complete_reviews[:3]]
        # results = self.classifier(complete_reviews[:5], labels, multilabel=True)

        result = results[0]

        _sequence = result['sequence']
        _labels = result['labels']
        _scores = result['scores']

        result = {'review': _sequence}
        result.update({l:s for l,s in zip(_labels, _scores)})

        result = pd.DataFrame.from_dict([result])
        return result

# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd
#from ..config import input_url, extension, scrap_tag, scrap_class

input_url = "https://fr.trustpilot.com/review/"
#input_url = "https://fr.trustpilot.com/"
extension = '.eu'

scrap_tag = {'card': 'div', 'title': 'h2', 'rating': 'div', 'review': 'p', 'date': 'p', 'reply': 'p'}
scrap_class = {'card': "styles_cardWrapper__LcCPA", 'title': 'typography_heading-s__f7029',
               'rating': 'styles_reviewHeader__iU9Px', 'review': 'typography_body-l__KUYFJ',
               'date': 'typography_body-m__xgxZ_', 'reply': 'typography_body-m__xgxZ_'}



class ReviewScrapper:

    def __init__(self, company: str, page_max=100):
        url_to_scrap = input_url + company 
        self.url = url_to_scrap
        self.page_max = page_max

    def scrap_data(self):
        titles = []
        ratings = []
        reviews = []
        dates = []
        replies = []
        reply_dates = []
        for index in range(self.number_of_pages):
            url = self.url + "?page=" + str(index + 1)
            print('Scrapping page ',index, ' from url ', url)
            soup = self._get_soup(url)
            _titles, _ratings, _reviews, _dates, _replies, _reply_dates = self._get_content(soup)
            titles += _titles
            ratings += _ratings
            reviews += _reviews
            dates += _dates
            replies += _replies
            reply_dates += _reply_dates
        reviews_dict = {'titles': titles, 'ratings': ratings, 'reviews': reviews,
                        'dates': dates, 'replies': replies, 'reply_dates': reply_dates}
        reviews_df = pd.DataFrame.from_dict(reviews_dict)
        return reviews_df

    @staticmethod
    def _get_soup(url: str) -> BeautifulSoup:
        page = requests.get(url)
        soup = BeautifulSoup(page.content, 'html.parser')
        return soup

    @staticmethod
    def _get_content(soup: BeautifulSoup):

        def _get_review_title(_card: BeautifulSoup):
            paragraphs = _card.findAll(scrap_tag['title'], class_=scrap_class['title'])
            contents = paragraphs[0].contents if paragraphs else []
            review_title = ''
            for line in contents:
                review_title += str(line) if str(line) != '<br/>' else '\n'
            return review_title

        def _get_review_rating(_card: BeautifulSoup):
            paragraphs = _card.findAll(scrap_tag['rating'], class_=scrap_class['rating'])
            paragraph = paragraphs[0] if paragraphs and 0 < len(paragraphs) else '-1'
            rating = paragraph.get('data-service-review-rating')
            return rating

        def _get_review(_card: BeautifulSoup):
            paragraphs = _card.findAll(scrap_tag['review'], class_=scrap_class['review'])
            contents = paragraphs[0].contents if paragraphs else []
            review = ''
            for line in contents:
                review += str(line) if str(line) != '<br/>' else '\n'
            return review

        def _get_review_date(_card: BeautifulSoup):
            paragraphs = _card.findAll('time')
            date = paragraphs[0].get('datetime') if 0 < len(paragraphs) else ''
            return date

        """
        def _get_review_date(_card: BeautifulSoup):
            paragraphs = _card.findAll(scrap_tag['date'], class_=scrap_class['date'])
            contents = paragraphs[0].contents if paragraphs else []
            review_date = contents[-1] if 0 < len(contents) else ''
            return review_date
        """

        def _get_reply(_card: BeautifulSoup):
            paragraphs = _card.findAll(scrap_tag['reply'], class_=scrap_class['reply'])
            reply = ''
            if 1 < len(paragraphs):
                contents = paragraphs[2].contents if paragraphs else []
                if 0 < len(contents):
                    reply = contents[0]
            return reply

        def _get_reply_date(_card: BeautifulSoup):
            paragraphs = _card.findAll('time')
            reply_date = paragraphs[1].get('datetime') if 1 < len(paragraphs) else ''
            return reply_date

        titles, ratings, reviews, dates, replies, reply_dates = [], [], [], [], [], []
        cards = soup.findAll(scrap_tag['card'], class_=scrap_class['card'])
        if cards:
            for card in cards:
                titles.append(_get_review_title(card))
                ratings.append(_get_review_rating(card))
                reviews.append(_get_review(card))
                dates.append(_get_review_date(card))
                replies.append(_get_reply(card))
                reply_dates.append(_get_reply_date(card))
        content = titles, ratings, reviews, dates, replies, reply_dates
        return content

    @property
    def number_of_pages(self):
        num_of_pages = self.page_max
        # @Insaf # These lines of code will throw an error if the url is not as expected
        
        if 1 < self.page_max:
            soup = self._get_soup(self.url)
            content_for_pages = soup.findAll("script", id="__NEXT_DATA__")[0].contents[0]
            content_for_pages_json = json.loads(content_for_pages)
            num_of_pages: int = \
                content_for_pages_json.get('props').get('pageProps').get('filters').get('pagination').get('totalPages')
            num_of_pages = min(num_of_pages, self.page_max)
        
        return num_of_pages

# %%
# @Insaf : Here we can change the name of the company, which is not always the name, but sometimes another URL
#So depending on the company, we need to adjust this
#company = 'leocare.eu'
company = 'www.carrefour.fr'
# @Insaf : Also, we can set the number of returned pages, note that this takes time
max_pages = 100
#@Insaf : create an object from the ReviewScrapper class
RC= ReviewScrapper(company,max_pages)

# %%
# the data frame that will get the scrapped data:
carrefour_df = RC.scrap_data()
# Out:
# Scrapping page  0  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=1
# Scrapping page  1  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=2
# Scrapping page  2  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=3
# Scrapping page  3  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=4
# Scrapping page  4  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=5
# Scrapping page  5  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=6
# Scrapping page  6  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=7
# Scrapping page  7  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=8
# Scrapping page  8  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=9
# Scrapping page  9  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=10
# Scrapping page  10  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=11
# Scrapping page  11  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=12
# Scrapping page  12  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=13
# Scrapping page  13  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=14
# Scrapping page  14  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=15
# Scrapping page  15  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=16
# Scrapping page  16  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=17
# Scrapping page  17  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=18
# Scrapping page  18  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=19
# Scrapping page  19  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=20
# Scrapping page  20  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=21
# Scrapping page  21  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=22
# Scrapping page  22  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=23
# Scrapping page  23  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=24
# Scrapping page  24  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=25
# Scrapping page  25  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=26
# Scrapping page  26  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=27
# Scrapping page  27  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=28
# Scrapping page  28  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=29
# Scrapping page  29  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=30
# Scrapping page  30  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=31
# Scrapping page  31  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=32
# Scrapping page  32  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=33
# Scrapping page  33  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=34
# Scrapping page  34  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=35
# Scrapping page  35  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=36
# Scrapping page  36  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=37
# Scrapping page  37  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=38
# Scrapping page  38  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=39
# Scrapping page  39  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=40
# Scrapping page  40  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=41
# Scrapping page  41  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=42
# Scrapping page  42  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=43
# Scrapping page  43  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=44
# Scrapping page  44  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=45
# Scrapping page  45  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=46
# Scrapping page  46  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=47
# Scrapping page  47  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=48
# Scrapping page  48  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=49
# Scrapping page  49  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=50
# Scrapping page  50  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=51
# Scrapping page  51  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=52
# Scrapping page  52  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=53
# Scrapping page  53  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=54
# Scrapping page  54  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=55
# Scrapping page  55  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=56
# Scrapping page  56  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=57
# Scrapping page  57  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=58
# Scrapping page  58  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=59
# Scrapping page  59  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=60
# Scrapping page  60  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=61
# Scrapping page  61  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=62
# Scrapping page  62  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=63
# Scrapping page  63  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=64
# Scrapping page  64  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=65
# Scrapping page  65  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=66
# Scrapping page  66  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=67
# Scrapping page  67  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=68
# Scrapping page  68  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=69
# Scrapping page  69  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=70
# Scrapping page  70  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=71
# Scrapping page  71  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=72
# Scrapping page  72  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=73
# Scrapping page  73  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=74
# Scrapping page  74  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=75
# Scrapping page  75  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=76
# Scrapping page  76  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=77
# Scrapping page  77  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=78
# Scrapping page  78  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=79
# Scrapping page  79  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=80
# Scrapping page  80  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=81
# Scrapping page  81  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=82
# Scrapping page  82  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=83
# Scrapping page  83  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=84
# Scrapping page  84  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=85
# Scrapping page  85  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=86
# Scrapping page  86  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=87
# Scrapping page  87  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=88
# Scrapping page  88  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=89
# Scrapping page  89  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=90
# Scrapping page  90  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=91
# Scrapping page  91  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=92
# Scrapping page  92  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=93
# Scrapping page  93  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=94
# Scrapping page  94  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=95
# Scrapping page  95  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=96
# Scrapping page  96  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=97
# Scrapping page  97  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=98
# Scrapping page  98  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=99
# Scrapping page  99  from url  https://fr.trustpilot.com/review/www.carrefour.fr?page=100

# %%
CARREFOUR_DATA_FILEPATH  = "/Users/carlosito/Library/CloudStorage/OneDrive-Personal/Personal Document/Hexamind/hexamind_code/Carrefour/Clustering/FinalClassfier/data"
carrefour_df.to_csv("final_carrefour_df")

# %% [markdown]
# ## For E Leclerc

# %%
company = 'www.e-leclerc.com'
max_pages = 100
leclerc_RC= ReviewScrapper(company, max_pages)

# %%
leclerc_df = leclerc_RC.scrap_data()
# Out:
# Scrapping page  0  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=1
# Scrapping page  1  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=2
# Scrapping page  2  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=3
# Scrapping page  3  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=4
# Scrapping page  4  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=5
# Scrapping page  5  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=6
# Scrapping page  6  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=7
# Scrapping page  7  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=8
# Scrapping page  8  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=9
# Scrapping page  9  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=10
# Scrapping page  10  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=11
# Scrapping page  11  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=12
# Scrapping page  12  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=13
# Scrapping page  13  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=14
# Scrapping page  14  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=15
# Scrapping page  15  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=16
# Scrapping page  16  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=17
# Scrapping page  17  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=18
# Scrapping page  18  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=19
# Scrapping page  19  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=20
# Scrapping page  20  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=21
# Scrapping page  21  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=22
# Scrapping page  22  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=23
# Scrapping page  23  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=24
# Scrapping page  24  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=25
# Scrapping page  25  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=26
# Scrapping page  26  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=27
# Scrapping page  27  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=28
# Scrapping page  28  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=29
# Scrapping page  29  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=30
# Scrapping page  30  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=31
# Scrapping page  31  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=32
# Scrapping page  32  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=33
# Scrapping page  33  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=34
# Scrapping page  34  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=35
# Scrapping page  35  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=36
# Scrapping page  36  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=37
# Scrapping page  37  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=38
# Scrapping page  38  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=39
# Scrapping page  39  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=40
# Scrapping page  40  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=41
# Scrapping page  41  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=42
# Scrapping page  42  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=43
# Scrapping page  43  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=44
# Scrapping page  44  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=45
# Scrapping page  45  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=46
# Scrapping page  46  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=47
# Scrapping page  47  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=48
# Scrapping page  48  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=49
# Scrapping page  49  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=50
# Scrapping page  50  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=51
# Scrapping page  51  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=52
# Scrapping page  52  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=53
# Scrapping page  53  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=54
# Scrapping page  54  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=55
# Scrapping page  55  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=56
# Scrapping page  56  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=57
# Scrapping page  57  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=58
# Scrapping page  58  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=59
# Scrapping page  59  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=60
# Scrapping page  60  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=61
# Scrapping page  61  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=62
# Scrapping page  62  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=63
# Scrapping page  63  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=64
# Scrapping page  64  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=65
# Scrapping page  65  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=66
# Scrapping page  66  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=67
# Scrapping page  67  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=68
# Scrapping page  68  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=69
# Scrapping page  69  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=70
# Scrapping page  70  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=71
# Scrapping page  71  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=72
# Scrapping page  72  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=73
# Scrapping page  73  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=74
# Scrapping page  74  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=75
# Scrapping page  75  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=76
# Scrapping page  76  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=77
# Scrapping page  77  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=78
# Scrapping page  78  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=79
# Scrapping page  79  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=80
# Scrapping page  80  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=81
# Scrapping page  81  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=82
# Scrapping page  82  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=83
# Scrapping page  83  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=84
# Scrapping page  84  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=85
# Scrapping page  85  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=86
# Scrapping page  86  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=87
# Scrapping page  87  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=88
# Scrapping page  88  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=89
# Scrapping page  89  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=90
# Scrapping page  90  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=91
# Scrapping page  91  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=92
# Scrapping page  92  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=93
# Scrapping page  93  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=94
# Scrapping page  94  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=95
# Scrapping page  95  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=96
# Scrapping page  96  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=97
# Scrapping page  97  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=98
# Scrapping page  98  from url  https://fr.trustpilot.com/review/www.e-leclerc.com?page=99

# %%
leclerc_df.shape
# Out:
# (1971, 6)

# %% [markdown]
# ## For Auchan

# %%
company = 'www.auchan.fr'
max_pages = 100
auchan_RC= ReviewScrapper(company, max_pages)
auchan_df = auchan_RC.scrap_data()
print(auchan_df.shape)
# Out:
# Scrapping page  0  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=1
# Scrapping page  1  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=2
# Scrapping page  2  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=3
# Scrapping page  3  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=4
# Scrapping page  4  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=5
# Scrapping page  5  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=6
# Scrapping page  6  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=7
# Scrapping page  7  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=8
# Scrapping page  8  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=9
# Scrapping page  9  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=10
# Scrapping page  10  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=11
# Scrapping page  11  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=12
# Scrapping page  12  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=13
# Scrapping page  13  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=14
# Scrapping page  14  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=15
# Scrapping page  15  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=16
# Scrapping page  16  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=17
# Scrapping page  17  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=18
# Scrapping page  18  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=19
# Scrapping page  19  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=20
# Scrapping page  20  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=21
# Scrapping page  21  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=22
# Scrapping page  22  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=23
# Scrapping page  23  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=24
# Scrapping page  24  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=25
# Scrapping page  25  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=26
# Scrapping page  26  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=27
# Scrapping page  27  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=28
# Scrapping page  28  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=29
# Scrapping page  29  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=30
# Scrapping page  30  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=31
# Scrapping page  31  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=32
# Scrapping page  32  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=33
# Scrapping page  33  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=34
# Scrapping page  34  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=35
# Scrapping page  35  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=36
# Scrapping page  36  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=37
# Scrapping page  37  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=38
# Scrapping page  38  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=39
# Scrapping page  39  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=40
# Scrapping page  40  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=41
# Scrapping page  41  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=42
# Scrapping page  42  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=43
# Scrapping page  43  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=44
# Scrapping page  44  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=45
# Scrapping page  45  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=46
# Scrapping page  46  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=47
# Scrapping page  47  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=48
# Scrapping page  48  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=49
# Scrapping page  49  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=50
# Scrapping page  50  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=51
# Scrapping page  51  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=52
# Scrapping page  52  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=53
# Scrapping page  53  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=54
# Scrapping page  54  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=55
# Scrapping page  55  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=56
# Scrapping page  56  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=57
# Scrapping page  57  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=58
# Scrapping page  58  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=59
# Scrapping page  59  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=60
# Scrapping page  60  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=61
# Scrapping page  61  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=62
# Scrapping page  62  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=63
# Scrapping page  63  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=64
# Scrapping page  64  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=65
# Scrapping page  65  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=66
# Scrapping page  66  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=67
# Scrapping page  67  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=68
# Scrapping page  68  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=69
# Scrapping page  69  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=70
# Scrapping page  70  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=71
# Scrapping page  71  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=72
# Scrapping page  72  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=73
# Scrapping page  73  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=74
# Scrapping page  74  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=75
# Scrapping page  75  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=76
# Scrapping page  76  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=77
# Scrapping page  77  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=78
# Scrapping page  78  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=79
# Scrapping page  79  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=80
# Scrapping page  80  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=81
# Scrapping page  81  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=82
# Scrapping page  82  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=83
# Scrapping page  83  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=84
# Scrapping page  84  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=85
# Scrapping page  85  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=86
# Scrapping page  86  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=87
# Scrapping page  87  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=88
# Scrapping page  88  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=89
# Scrapping page  89  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=90
# Scrapping page  90  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=91
# Scrapping page  91  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=92
# Scrapping page  92  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=93
# Scrapping page  93  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=94
# Scrapping page  94  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=95
# Scrapping page  95  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=96
# Scrapping page  96  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=97
# Scrapping page  97  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=98
# Scrapping page  98  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=99
# Scrapping page  99  from url  https://fr.trustpilot.com/review/www.auchan.fr?page=100
# (2000, 6)

# %% [markdown]
# ## For Lidl

# %%
company = 'www.lidl.fr'
max_pages = 100
lidl_RC= ReviewScrapper(company, max_pages)
lidl_df = lidl_RC.scrap_data()
print(lidl_df.shape)
# Out:
# Scrapping page  0  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=1
# Scrapping page  1  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=2
# Scrapping page  2  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=3
# Scrapping page  3  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=4
# Scrapping page  4  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=5
# Scrapping page  5  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=6
# Scrapping page  6  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=7
# Scrapping page  7  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=8
# Scrapping page  8  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=9
# Scrapping page  9  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=10
# Scrapping page  10  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=11
# Scrapping page  11  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=12
# Scrapping page  12  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=13
# Scrapping page  13  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=14
# Scrapping page  14  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=15
# Scrapping page  15  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=16
# Scrapping page  16  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=17
# Scrapping page  17  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=18
# Scrapping page  18  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=19
# Scrapping page  19  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=20
# Scrapping page  20  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=21
# Scrapping page  21  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=22
# Scrapping page  22  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=23
# Scrapping page  23  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=24
# Scrapping page  24  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=25
# Scrapping page  25  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=26
# Scrapping page  26  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=27
# Scrapping page  27  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=28
# Scrapping page  28  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=29
# Scrapping page  29  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=30
# Scrapping page  30  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=31
# Scrapping page  31  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=32
# Scrapping page  32  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=33
# Scrapping page  33  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=34
# Scrapping page  34  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=35
# Scrapping page  35  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=36
# Scrapping page  36  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=37
# Scrapping page  37  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=38
# Scrapping page  38  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=39
# Scrapping page  39  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=40
# Scrapping page  40  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=41
# Scrapping page  41  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=42
# Scrapping page  42  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=43
# Scrapping page  43  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=44
# Scrapping page  44  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=45
# Scrapping page  45  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=46
# Scrapping page  46  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=47
# Scrapping page  47  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=48
# Scrapping page  48  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=49
# Scrapping page  49  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=50
# Scrapping page  50  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=51
# Scrapping page  51  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=52
# Scrapping page  52  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=53
# Scrapping page  53  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=54
# Scrapping page  54  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=55
# Scrapping page  55  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=56
# Scrapping page  56  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=57
# Scrapping page  57  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=58
# Scrapping page  58  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=59
# Scrapping page  59  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=60
# Scrapping page  60  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=61
# Scrapping page  61  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=62
# Scrapping page  62  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=63
# Scrapping page  63  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=64
# Scrapping page  64  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=65
# Scrapping page  65  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=66
# Scrapping page  66  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=67
# Scrapping page  67  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=68
# Scrapping page  68  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=69
# Scrapping page  69  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=70
# Scrapping page  70  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=71
# Scrapping page  71  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=72
# Scrapping page  72  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=73
# Scrapping page  73  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=74
# Scrapping page  74  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=75
# Scrapping page  75  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=76
# Scrapping page  76  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=77
# Scrapping page  77  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=78
# Scrapping page  78  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=79
# Scrapping page  79  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=80
# Scrapping page  80  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=81
# Scrapping page  81  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=82
# Scrapping page  82  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=83
# Scrapping page  83  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=84
# Scrapping page  84  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=85
# Scrapping page  85  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=86
# Scrapping page  86  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=87
# Scrapping page  87  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=88
# Scrapping page  88  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=89
# Scrapping page  89  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=90
# Scrapping page  90  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=91
# Scrapping page  91  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=92
# Scrapping page  92  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=93
# Scrapping page  93  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=94
# Scrapping page  94  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=95
# Scrapping page  95  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=96
# Scrapping page  96  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=97
# Scrapping page  97  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=98
# Scrapping page  98  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=99
# Scrapping page  99  from url  https://fr.trustpilot.com/review/www.lidl.fr?page=100
# (2000, 6)

# %%
lidl_df.to_csv("final_lidl_df.csv")
auchan_df.to_csv("final_auchan_df.csv")
leclerc_df.to_csv("final_leclerc_df.csv")
